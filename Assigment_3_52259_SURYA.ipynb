# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishik27-12/NLP/blob/main/Assigment_3_52263_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# -- tags--   task 1

# %%
import nltk
import spacy

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt_tab') # Added to download the missing resource
sentence = "Students are learning Natural Language Processing"
tokens = nltk.word_tokenize(sentence)
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [('Students', 'NNS'), ('are', 'VBP'), ('learning', 'VBG'), ('Natural', 'NNP'), ('Language', 'NNP'), ('Processing', 'NNP')]

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

doc = nlp("Students are learing Natural Language Processing")
for token in doc:
    print(token.text, token.pos_)
# Out:
# Students NOUN
# are AUX
# learing VERB
# Natural PROPN
# Language PROPN
# Processing NOUN

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying a startup in India.")
for token in doc:
    print(token.text, token.pos_, token.tag_)
# Out:
# Apple PROPN NNP
# is AUX VBZ
# looking VERB VBG
# at ADP IN
# buying VERB VBG
# a DET DT
# startup NOUN NN
# in ADP IN
# India PROPN NNP
# . PUNCT .

# %%
import spacy
from collections import Counter
import subprocess
import sys

# Attempt to load the model, if not found, download it
try:
    nlp = spacy.load("en_core_web_sm") # Changed to specific model name
except OSError:
    print("Downloading en_core_web_sm model...")
    # Use subprocess to run the pip install command for the spacy model package
    subprocess.check_call([sys.executable, "-m", "pip", "install", "en_core_web_sm"])
    nlp = spacy.load("en_core_web_sm") # Load the specific model name after installation

text = "Loving the new AI features 😂 #AI #MachineLearning"
doc = nlp(text)
pos_counts = Counter([token.pos_ for token in doc])

nouns = []
verbs = []

for token in doc:
  if token.pos_ in ["NOUN", "PROPN"]:
    nouns.append(token.text)
  elif token.pos_ == "VERB":
    verbs.append(token.text)

noun_freq = Counter(nouns)
verb_freq = Counter(verbs)

print("Noun Frequencies:", noun_freq)
print("Verb Frequencies:", verb_freq)
# Out:
# Noun Frequencies: Counter({'AI': 2, '😂': 1, 'MachineLearning': 1})
# Verb Frequencies: Counter({'Loving': 1, 'features': 1})

# %% [markdown]
# ------------ SR University  tagging POS--------- task 2 -----
#
# -------------------------------------------------------------

# %%
SRUniversity="""The SR University campus is located in Ananthasagar village of Hasanparthy Mandal in Warangal, Telangana, India.
It is in 150 acres, with both separate hostel facilities for boys and girls.
There is a huge central library along with Indias largest Technology Business Incubator (TBI) in tier 2 cities."""

# %%
nltk.download('averaged_perceptron_tagger')
from nltk import word_tokenize
words =  word_tokenize(SRUniversity)
nltk.pos_tag(words)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('The', 'DT'),
#  ('SR', 'NNP'),
#  ('University', 'NNP'),
#  ('campus', 'NN'),
#  ('is', 'VBZ'),
#  ('located', 'VBN'),
#  ('in', 'IN'),
#  ('Ananthasagar', 'NNP'),
#  ('village', 'NN'),
#  ('of', 'IN'),
#  ('Hasanparthy', 'NNP'),
#  ('Mandal', 'NNP'),
#  ('in', 'IN'),
#  ('Warangal', 'NNP'),
#  (',', ','),
#  ('Telangana', 'NNP'),
#  (',', ','),
#  ('India', 'NNP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('in', 'IN'),
#  ('150', 'CD'),
#  ('acres', 'NNS'),
#  (',', ','),
#  ('with', 'IN'),
#  ('both', 'DT'),
#  ('separate', 'JJ'),
#  ('hostel', 'NN'),
#  ('facilities', 'NNS'),
#  ('for', 'IN'),
#  ('boys', 'NNS'),
#  ('and', 'CC'),
#  ('girls', 'NNS'),
#  ('.', '.'),
#  ('There', 'EX'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('huge', 'JJ'),
#  ('central', 'JJ'),
# ...

# %%
import nltk
nltk.download('tagsets')
nltk.download('tagsets_json') # Added to download the missing resource
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
# ...

# %% [markdown]
# -------- ASSIGNMENT 3 ---------task 3----------
#
# ----------------------------------------------------------

# %%
import json

# Path to the JSON file
json_file_path = '/content/enriched_posts.json'

# Read the JSON file
with open(json_file_path, 'r') as f:
    data = json.load(f)

# Assuming the JSON contains a list of dictionaries and each dictionary has a 'text' key
# We will take the text from the first entry for demonstration as in Assignment 3
if data and isinstance(data, list) and 'text' in data[0]:
    assignment3_text = data[0]['text']
    print("Successfully loaded text from JSON file for Assignment 3:")
    print(assignment3_text)
else:
    print("Could not extract text. Please check the JSON file format.")
# Out:
# Successfully loaded text from JSON file for Assignment 3:
# Just saw a LinkedIn Influencer with 'Organic Growth' written in the profile with 65K+ followers claiming that he can help you in growing your platform, copying the posts from other influencers.

# %% [markdown]
# ### NLTK Part-of-Speech Tagging for `assignment3_text` (from JSON file)

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Using the text extracted from the JSON for Assignment 3
text_for_analysis = assignment3_text

tokens = nltk.word_tokenize(text_for_analysis)
pos_tags = nltk.pos_tag(tokens)
print("NLTK POS Tags:", pos_tags)
# Out:
# NLTK POS Tags: [('Just', 'RB'), ('saw', 'VBD'), ('a', 'DT'), ('LinkedIn', 'NNP'), ('Influencer', 'NNP'), ('with', 'IN'), ("'Organic", 'JJ'), ('Growth', 'NNP'), ("'", 'POS'), ('written', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('profile', 'NN'), ('with', 'IN'), ('65K+', 'CD'), ('followers', 'NNS'), ('claiming', 'VBG'), ('that', 'IN'), ('he', 'PRP'), ('can', 'MD'), ('help', 'VB'), ('you', 'PRP'), ('in', 'IN'), ('growing', 'VBG'), ('your', 'PRP$'), ('platform', 'NN'), (',', ','), ('copying', 'VBG'), ('the', 'DT'), ('posts', 'NNS'), ('from', 'IN'), ('other', 'JJ'), ('influencers', 'NNS'), ('.', '.')]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ### spaCy Part-of-Speech Tagging and Frequency Analysis for `assignment3_text` (from JSON file)

# %%
import spacy
from collections import Counter
import subprocess
import sys

# Attempt to load the model, if not found, download it
try:
    nlp = spacy.load("en_core_web_sm")
except OSError:
    print("Downloading en_core_web_sm model...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "en_core_web_sm"])
    nlp = spacy.load("en_core_web_sm")

# Using the text extracted from the JSON for Assignment 3
text_for_analysis = assignment3_text

doc = nlp(text_for_analysis)

print("SpaCy POS Tags (Token, Universal POS, Detailed Tag):")
for token in doc:
    print(token.text, token.pos_, token.tag_)

pos_counts = Counter([token.pos_ for token in doc])

nouns = []
verbs = []

for token in doc:
  if token.pos_ in ["NOUN", "PROPN"]:
    nouns.append(token.text)
  elif token.pos_ == "VERB":
    verbs.append(token.text)

noun_freq = Counter(nouns)
verb_freq = Counter(verbs)

print("\nNoun Frequencies:", noun_freq)
print("Verb Frequencies:", verb_freq)
# Out:
# SpaCy POS Tags (Token, Universal POS, Detailed Tag):
# Just ADV RB
# saw VERB VBD
# a DET DT
# LinkedIn NOUN NN
# Influencer NOUN NN
# with ADP IN
# ' PUNCT ``
# Organic PROPN NNP
# Growth PROPN NNP
# ' PUNCT ''
# written VERB VBN
# in ADP IN
# the DET DT
# profile NOUN NN
# with ADP IN
# 65K+ PROPN NNP
# followers NOUN NNS
# claiming VERB VBG
# that SCONJ IN
# he PRON PRP
# can AUX MD
# help VERB VB
# you PRON PRP
# in ADP IN
# growing VERB VBG
# your PRON PRP$
# platform NOUN NN
# , PUNCT ,
# copying VERB VBG
# the DET DT
# posts NOUN NNS
# from ADP IN
# other ADJ JJ
# influencers NOUN NNS
# . PUNCT .
#
# Noun Frequencies: Counter({'LinkedIn': 1, 'Influencer': 1, 'Organic': 1, 'Growth': 1, 'profile': 1, '65K+': 1, 'followers': 1, 'platform': 1, 'posts': 1, 'influencers': 1})
# Verb Frequencies: Counter({'saw': 1, 'written': 1, 'claiming': 1, 'help': 1, 'growing': 1, 'copying': 1})

# %%
text = "Jobseekers, this one’s for you. Every application, every interview, every follow-up… the pressure is immense. And I know what you're thinking: Am I not good enough? But let me tell you, this isn’t about you or your skills. It’s about a broken system where 60% of applicants never hear back. Your mental health is not worth sacrificing for a system that doesn’t acknowledge your worth. Please remember, taking care of yourself is the real priority. Your dream job will come, but for now, breathe. 🌻"

# %%
import nltk
nltk.download('averaged_perceptron_tagger')

text = "Jobseekers, this one’s for you. Every application, every interview, every follow-up… the pressure is immense. And I know what you're thinking: Am I not good enough? But let me tell you, this isn’t about you or your skills. It’s about a broken system where 60% of applicants never hear back. Your mental health is not worth sacrificing for a system that doesn’t acknowledge your worth. Please remember, taking care of yourself is the real priority. Your dream job will come, but for now, breathe. 🌻"

tokens = nltk.word_tokenize(text)
pos_tags = nltk.pos_tag(tokens)
print(pos_tags)
# Out:
# [('Jobseekers', 'NNS'), (',', ','), ('this', 'DT'), ('one', 'CD'), ('’', 'NN'), ('s', 'NN'), ('for', 'IN'), ('you', 'PRP'), ('.', '.'), ('Every', 'DT'), ('application', 'NN'), (',', ','), ('every', 'DT'), ('interview', 'NN'), (',', ','), ('every', 'DT'), ('follow-up…', 'CD'), ('the', 'DT'), ('pressure', 'NN'), ('is', 'VBZ'), ('immense', 'JJ'), ('.', '.'), ('And', 'CC'), ('I', 'PRP'), ('know', 'VBP'), ('what', 'WP'), ('you', 'PRP'), ("'re", 'VBP'), ('thinking', 'VBG'), (':', ':'), ('Am', 'NN'), ('I', 'PRP'), ('not', 'RB'), ('good', 'JJ'), ('enough', 'RB'), ('?', '.'), ('But', 'CC'), ('let', 'VB'), ('me', 'PRP'), ('tell', 'VB'), ('you', 'PRP'), (',', ','), ('this', 'DT'), ('isn', 'NN'), ('’', 'VBZ'), ('t', 'VBP'), ('about', 'IN'), ('you', 'PRP'), ('or', 'CC'), ('your', 'PRP$'), ('skills', 'NNS'), ('.', '.'), ('It', 'PRP'), ('’', 'VBZ'), ('s', 'JJ'), ('about', 'IN'), ('a', 'DT'), ('broken', 'NN'), ('system', 'NN'), ('where', 'WRB'), ('60', 'CD'), ('%', 'NN'), ('of', 'IN'), ('applicants'
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Jobseekers, this one’s for you. Every application, every interview, every follow-up… the pressure is immense. And I know what you're thinking: Am I not good enough? But let me tell you, this isn’t about you or your skills. It’s about a broken system where 60% of applicants never hear back. Your mental health is not worth sacrificing for a system that doesn’t acknowledge your worth. Please remember, taking care of yourself is the real priority. Your dream job will come, but for now, breathe. 🌻")
for token in doc:
  print(token.text , token.pos_)
# Out:
# Jobseekers NOUN
# , PUNCT
# this DET
# one NOUN
# ’s VERB
# for ADP
# you PRON
# . PUNCT
# Every DET
# application NOUN
# , PUNCT
# every DET
# interview NOUN
# , PUNCT
# every DET
# follow NOUN
# - PUNCT
# up NOUN
# … PUNCT
# the DET
# pressure NOUN
# is AUX
# immense ADJ
# . PUNCT
# And CCONJ
# I PRON
# know VERB
# what PRON
# you PRON
# 're AUX
# thinking VERB
# : PUNCT
# Am AUX
# I PRON
# not PART
# good ADJ
# enough ADV
# ? PUNCT
# But CCONJ
# let VERB
# me PRON
# tell VERB
# you PRON
# , PUNCT
# this PRON
# is AUX
# n’t NOUN
# about ADP
# you PRON
# or CCONJ
# your PRON
# skills NOUN
# . PUNCT
# It PRON
# ’s VERB
# about ADP
# a DET
# broken ADJ
# system NOUN
# where SCONJ
# 60 NUM
# % NOUN
# of ADP
# applicants NOUN
# never ADV
# hear VERB
# back ADV
# . PUNCT
# Your PRON
# mental ADJ
# health NOUN
# is AUX
# not PART
# worth ADJ
# sacrificing VERB
# for ADP
# a DET
# system NOUN
# that PRON
# does AUX
# n’t PART
# acknowledge VERB
# your PRON
# worth NOUN
# . PUNCT
# ...

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

doc = nlp("Jobseekers, this one’s for you. Every application, every interview, every follow-up… the pressure is immense. And I know what you're thinking: Am I not good enough? But let me tell you, this isn’t about you or your skills. It’s about a broken system where 60% of applicants never hear back. Your mental health is not worth sacrificing for a system that doesn’t acknowledge your worth. Please remember, taking care of yourself is the real priority. Your dream job will come, but for now, breathe. 🌻")
for token in doc:
  print(token.text , token.pos_, token.tag_)
# Out:
# Jobseekers NOUN NNS
# , PUNCT ,
# this DET DT
# one NOUN NN
# ’s VERB VBP
# for ADP IN
# you PRON PRP
# . PUNCT .
# Every DET DT
# application NOUN NN
# , PUNCT ,
# every DET DT
# interview NOUN NN
# , PUNCT ,
# every DET DT
# follow NOUN NN
# - PUNCT HYPH
# up NOUN NN
# … PUNCT NFP
# the DET DT
# pressure NOUN NN
# is AUX VBZ
# immense ADJ JJ
# . PUNCT .
# And CCONJ CC
# I PRON PRP
# know VERB VBP
# what PRON WP
# you PRON PRP
# 're AUX VBP
# thinking VERB VBG
# : PUNCT :
# Am AUX VBP
# I PRON PRP
# not PART RB
# good ADJ JJ
# enough ADV RB
# ? PUNCT .
# But CCONJ CC
# let VERB VB
# me PRON PRP
# tell VERB VB
# you PRON PRP
# , PUNCT ,
# this PRON DT
# is AUX VBZ
# n’t NOUN NN
# about ADP IN
# you PRON PRP
# or CCONJ CC
# your PRON PRP$
# skills NOUN NNS
# . PUNCT .
# It PRON PRP
# ’s VERB VBZ
# about ADP IN
# a DET DT
# broken ADJ JJ
# system NOUN NN
# where SCONJ WRB
# 60 NUM CD
# % NOUN NN
# of ADP IN
# applicants NOUN NNS
# never ADV RB
# hear VERB VB
# back ADV RB
# . PUNCT .
# ...

# %%
import spacy
from collections import Counter
import subprocess
import sys

# Attempt to load the model, if not found, download it
try:
    nlp = spacy.load("en_core_web_sm") # Changed to specific model name
except OSError:
    print("Downloading en_core_web_sm model...")
    # Use subprocess to run the pip install command for the spacy model package
    subprocess.check_call([sys.executable, "-m", "pip", "install", "en_core_web_sm"])
    nlp = spacy.load("en_core_web_sm") # Load the specific model name after installation

text = "Jobseekers, this one’s for you. Every application, every interview, every follow-up… the pressure is immense. And I know what you're thinking: Am I not good enough? But let me tell you, this isn’t about you or your skills. It’s about a broken system where 60% of applicants never hear back. Your mental health is not worth sacrificing for a system that doesn’t acknowledge your worth. Please remember, taking care of yourself is the real priority. Your dream job will come, but for now, breathe. 🌻"

doc = nlp(text)
pos_counts = Counter([token.pos_ for token in doc])

nouns = []
verbs = []

for token in doc:
  if token.pos_ in ["NOUN", "PROPN"]:
    nouns.append(token.text)
  elif token.pos_ == "VERB":
    verbs.append(token.text)

noun_freq = Counter(nouns)
verb_freq = Counter(verbs)

print("Noun Frequencies:", noun_freq)
print("Verb Frequencies:", verb_freq)
# Out:
# Noun Frequencies: Counter({'system': 2, 'Jobseekers': 1, 'one': 1, 'application': 1, 'interview': 1, 'follow': 1, 'up': 1, 'pressure': 1, 'n’t': 1, 'skills': 1, '%': 1, 'applicants': 1, 'health': 1, 'worth': 1, 'care': 1, 'priority': 1, 'dream': 1, 'job': 1, 'breathe': 1, '🌻': 1})
# Verb Frequencies: Counter({'’s': 2, 'know': 1, 'thinking': 1, 'let': 1, 'tell': 1, 'hear': 1, 'sacrificing': 1, 'acknowledge': 1, 'remember': 1, 'taking': 1, 'come': 1})
