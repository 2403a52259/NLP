# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishik27-12/NLP/blob/main/RISHIK_2403A52263_NLP_AIAIB10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk

# %%
pip install spacy

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
import spacy

# %%
text = "NEWTONS LAW OF GRAVITION EXPLAINS THE UNIVERSAL GRAVITATION IN CLASSICAL PHYSICS"
words = text.split()
print(words)
# Out:
# ['NEWTONS', 'LAW', 'OF', 'GRAVITION', 'EXPLAINS', 'THE', 'UNIVERSAL', 'GRAVITATION', 'IN', 'CLASSICAL', 'PHYSICS']

# %%
words=text.split()
word_count = len(words)
print("no of words:",word_count)
# Out:
# no of words: 11

# %%
lower_case_text = text.lower()
print("Lower case text:")
print(lower_case_text)
# Out:
# Lower case text:
# newtons law of gravition explains the universal gravitation in classical physics
